# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel("C:/Users/subha/OneDrive/Desktop/Clg Asst/WORK-DATA/EXCEL/quality_ban.xlsx")
print(data)
# Out:
#       Size  Weight  HarvestTime  Ripeness  Sweetness  Softness  Acidity  \
# 0        2    0.47          108         3   3.077832  1.472177        1
# 1        3    0.49          326         3   0.346921  2.495099        1
# 2        1    1.48          237         4   1.568452  2.645145        2
# 3        1    1.57          368         2   1.889605  1.273761        1
# 4        1    1.32          523         2   0.022459  1.209709        3
# ...    ...     ...          ...       ...        ...       ...      ...
# 7995     7    0.72          109         1   1.134953  2.952763        3
# 7996     1    2.22          484         3   2.812175  0.489249        3
# 7997     2    1.91          206         2   2.532364  0.964976        1
# 7998     3    2.74          293         4   1.008029  2.126946        1
# 7999     3    2.04          578         2   0.159026  1.499706        2
#
#      Quality
# 0       Good
# 1       Good
# 2       Good
# 3       Good
# 4       Good
# ...      ...
# 7995     Bad
# 7996     Bad
# 7997     Bad
# 7998     Bad
# 7999     Bad
#
# [8000 rows x 8 columns]

# %%
data.head()
# Out:
#    Size  Weight  HarvestTime  Ripeness  Sweetness  Softness  Acidity Quality
# 0     2    0.47          108         3   3.077832  1.472177        1    Good
# 1     3    0.49          326         3   0.346921  2.495099        1    Good
# 2     1    1.48          237         4   1.568452  2.645145        2    Good
# 3     1    1.57          368         2   1.889605  1.273761        1    Good
# 4     1    1.32          523         2   0.022459  1.209709        3    Good

# %%
data.describe()
# Out:
#               Size       Weight  HarvestTime     Ripeness    Sweetness  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean      2.380250     1.786018   640.959750     2.380500     1.729725
# std       1.287388     1.205348   442.818552     1.274038     1.182147
# min       1.000000     0.000000     1.000000     1.000000     0.000319
# 25%       1.000000     0.830000   290.000000     1.000000     0.778816
# 50%       2.000000     1.610000   569.000000     2.000000     1.551058
# 75%       3.000000     2.540000   923.000000     3.000000     2.464903
# max       8.000000     8.280000  2764.000000     8.000000     7.539374
#
#           Softness      Acidity
# count  8000.000000  8000.000000
# mean      1.718398     2.399000
# std       1.145455     1.325903
# min       0.000386     1.000000
# 25%       0.839486     1.000000
# 50%       1.568537     2.000000
# 75%       2.364573     3.000000
# max       8.241555     9.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         8000 non-null   int64
#  1   Weight       8000 non-null   float64
#  2   HarvestTime  8000 non-null   int64
#  3   Ripeness     8000 non-null   int64
#  4   Sweetness    8000 non-null   float64
#  5   Softness     8000 non-null   float64
#  6   Acidity      8000 non-null   int64
#  7   Quality      8000 non-null   object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 500.1+ KB

# %%
data ["Quality"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Good
# 1       Good
# 2       Good
# 3       Good
# 4       Good
#         ...
# 7995     Bad
# 7996     Bad
# 7997     Bad
# 7998     Bad
# 7999     Bad
# Name: Quality, Length: 8000, dtype: object>

# %%
for feature in ['Weight', 'Size', 'Sweetness','Ripeness','Acidity']:
    sns.histplot(data[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()
# Out:
# C:\Users\subha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\subha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\subha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\subha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\subha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
